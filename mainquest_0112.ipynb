# %%
import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        Account.account_count += 1

        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.accountnumber = self.create_account_number()

        self.deposit_count = 0

    def create_account_number(self):
        return (
            f"{random.randint(0, 999):03}-"
            f"{random.randint(0, 99):02}-"
            f"{random.randint(0, 999999):06}"
        )

    @classmethod
    def get_account_num(cls):
        return cls.account_count

    def deposit(self, amount):
        if amount < 1:
            print("입금은 최소 1원 이상만 가능합니다.")
            return False

        self.balance += amount
        self.deposit_count += 1

        if self.deposit_count % 5 == 0:
            interest = int(self.balance * 0.01)
            self.balance += interest
            print(f"{interest}원의 이자가 추가되었습니다.")

        print(f"{amount}원이 입금되었습니다. 현재 잔액은 {self.balance}원 입니다.")
        return True

    def withdraw(self, amount):
        if amount > self.balance:
            print("잔액이 부족합니다.")
            return False

        self.balance -= amount
        print(f"{amount}원이 출금되었습니다. 현재 잔액은 {self.balance}원 입니다.")
        return True

    def display_info(self):
        print(
            f"은행이름: {self.bank}, "
            f"예금주: {self.owner}, "
            f"계좌번호: {self.accountnumber}, "
            f"잔고: {self.balance:,}원"
        )

# %%
a = Account("파이썬", 10000)
b = Account("자바", 20000)
c = Account("루비", 30000)

accounts = [a, b, c]

for acc in accounts:
    for i in range(5):
        acc.deposit(1000)

    acc.display_info()
    print()
# Out:
# 1000원이 입금되었습니다. 현재 잔액은 11000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 12000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 13000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 14000원 입니다.
# 150원의 이자가 추가되었습니다.
# 1000원이 입금되었습니다. 현재 잔액은 15150원 입니다.
# 은행이름: SC은행, 예금주: 파이썬, 계좌번호: 344-42-878030, 잔고: 15,150원
#
# 1000원이 입금되었습니다. 현재 잔액은 21000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 22000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 23000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 24000원 입니다.
# 250원의 이자가 추가되었습니다.
# 1000원이 입금되었습니다. 현재 잔액은 25250원 입니다.
# 은행이름: SC은행, 예금주: 자바, 계좌번호: 667-08-996561, 잔고: 25,250원
#
# 1000원이 입금되었습니다. 현재 잔액은 31000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 32000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 33000원 입니다.
# 1000원이 입금되었습니다. 현재 잔액은 34000원 입니다.
# 350원의 이자가 추가되었습니다.
# 1000원이 입금되었습니다. 현재 잔액은 35350원 입니다.
# 은행이름: SC은행, 예금주: 루비, 계좌번호: 290-75-035770, 잔고: 35,350원
